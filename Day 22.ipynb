# %% [markdown]
# # Day 22

# %% [markdown]
# ###  1) Read a jpeg image and print the image file

# %%
from PIL import Image , ImageFilter
img = Image.open('C:\\Users\\Sejal J Nagbhidkar\\OneDrive\\Desktop\\1.jpg')
filter_image = img.filter(ImageFilter.BLUR)
filter_image.save("C:\\Users\\Sejal J Nagbhidkar\\OneDrive\\Desktop\\blur.jpg","png")
print(img.format)
# Out:
# JPEG

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %% [markdown]
# ###   2) Merge two pdf files using python script

# %%
import PyPDF2 
 
pdf1File = open('C:\\Users\\Sejal J Nagbhidkar\\day 22\\industrial-practice-1.pdf', 'rb')
pdf2File = open('C:\\Users\\Sejal J Nagbhidkar\\day 22\\PRACTICE.pdf', 'rb')
 
pdf1Reader = PyPDF2.PdfFileReader(pdf1File)
pdf2Reader = PyPDF2.PdfFileReader(pdf2File)

pdfWriter = PyPDF2.PdfFileWriter()
 

for pageNum in range(pdf1Reader.numPages):
    pageObj = pdf1Reader.getPage(pageNum)
    pdfWriter.addPage(pageObj)

for pageNum in range(pdf2Reader.numPages):
    pageObj = pdf2Reader.getPage(pageNum)
    pdfWriter.addPage(pageObj)
    
pdfOutputFile = open('MergedFiles.pdf', 'wb')
pdfWriter.write(pdfOutputFile)

pdfOutputFile.close()
pdf1File.close()
pdf2File.close()

# %% [markdown]
# ### 3) Scrape a website and store the data into DB.

# %%
import requests
import MySQLdb
from bs4 import BeautifulSoup

# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="Sejal@123",
  database="mydatabase"
)
dbse = mydb.cursor()
url_to_scrape = 'https://www.google.com'
plain_html_text = requests.get(url_to_scrape)
soup = BeautifulSoup(plain_html_text.text, "html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/WebPage" lang="en-IN">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/>
#   <title>
#    Google
#   </title>
#   <script nonce="8PI1lOlwLBrkJwLUMsRrAg==">
# ...

# %% [markdown]
# ### 4) Write queries to filter the data in db

# %%
import mysql.connector
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Sejal@123",
    database="mydatabase"
)
db = mydb.cursor()
sql = "SELECT * FROM hospital WHERE patients_visited > 2"
db.execute(sql)
myresult = db.fetchall()
for x in myresult:
    print(x)
# Out:
# ('Dr.Harsh', 1001, 7)
# ('Dr.Nidhi', 1002, 3)
# ('Dr.Prathmesh', 1003, 8)
# ('Dr.Niraj', 1005, 6)
# ('Dr.Ravish', 1006, 4)
# ('Dr.Tanu', 1008, 9)
# ('Dr.Guri', 1009, 3)
